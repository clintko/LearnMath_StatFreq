# %% [markdown]
# # Set up Environment

# %%
library(tidyverse)
options(repr.plot.width=2, repr.plot.height=3)

workdir <- "/media/clint/Data/GitRepo/Statistics/BIOS706/Midterm"
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
# ✔ ggplot2 2.2.1     ✔ purrr   0.2.4
# ✔ tibble  1.4.2     ✔ dplyr   0.7.4
# ✔ tidyr   0.7.2     ✔ stringr 1.2.0
# ✔ readr   1.1.1     ✔ forcats 0.2.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %% [markdown]
# # Read in data and Preprocess

# %%
dat_frmgham <- read_csv(file.path(workdir, "frmgham2.csv"))
# Out:
# Parsed with column specification:
# cols(
#   .default = col_integer(),
#   SYSBP = col_double(),
#   DIABP = col_double(),
#   BMI = col_double()
# )
# See spec(...) for full column specifications.

# %%
dat <- dat_frmgham
dat$SEX2      <- c("Men", "Women")[dat$SEX]
dat$DIABETES2 <- c("Not a diabetic", "Diabetic")[dat$DIABETES + 1]
dat$AGE2      <- cut(dat$AGE, c(30, 40, 50, 65, 70, 80))
dat_prep      <- dat
dim(dat_prep)
# Out:
# [1] 11627    42

# %% [markdown]
# # Aim 1
# **Describe the distribution of heart rate and diabetes and test for the association of heart rate and diabetes in Period 1.**

# %%
dat <- dat_prep
dat_per01 <- dat %>% 
    filter(PERIOD == 1) %>%
    select(HEARTRTE, DIABETES, DIABETES2, SEX, SEX2)

# %%
options(repr.plot.width=2, repr.plot.height=3)

dat_per01 %>% 
    ggplot(aes(x = HEARTRTE)) + 
    geom_histogram(
        aes(y = ..density..),
        binwidth = 5) +
    facet_grid(DIABETES2~., scales = "fixed")
# Out:
# Warning message:
# “Removed 1 rows containing non-finite values (stat_bin).”
# plot without title

# %%
dat <- dat_per01
dat <- split(dat$HEARTRTE, dat$DIABETES2)
t.test(dat$`Not a diabetic`, dat$Diabetic)
# Out:
# 	Welch Two Sample t-test
#
# data:  dat$`Not a diabetic` and dat$Diabetic
# t = -3.3715, df = 126.97, p-value = 0.0009912
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -5.908105 -1.537839
# sample estimates:
# mean of x mean of y
#  75.78942  79.51240

# %% [markdown]
# # Aim 2
# **Describe the distribution of heart rate and diabetes by age and sex and test for the association heart rate and diabetes by age in Period 1.**

# %%
dat <- dat_prep

dat_per01 <- dat %>% 
    filter(PERIOD == 1) %>%
    select(HEARTRTE, DIABETES, DIABETES2, SEX, SEX2, AGE)

dat_per01$AGE2 <- cut(dat_per01$AGE, c(30, 40, 50, 65, 70, 80))

# %%
options(repr.plot.width=3, repr.plot.height=3)

dat_per01 %>% 
    ggplot(aes(x = HEARTRTE)) + 
    geom_histogram(
        aes(y = ..density..),
        binwidth = 5) +
    facet_grid(DIABETES2~SEX2, scales = "fixed")
# Out:
# Warning message:
# “Removed 1 rows containing non-finite values (stat_bin).”
# plot without title

# %%
dat <- dat_per01
dat <- dat %>% 
    group_by(DIABETES2, SEX2, AGE2) %>%
    summarize(Mean_HEARTRTE = mean(HEARTRTE, na.rm = TRUE))

# %%
options(repr.plot.width=5, repr.plot.height=5)

# set color scale
sc <- scale_fill_distiller(
    palette="RdYlBu", direction=-1,
    limits=c(70,90))

dat %>% 
    ggplot(aes(x = SEX2, y = AGE2, fill = Mean_HEARTRTE)) + 
    sc + 
    geom_tile() +
    facet_grid(~DIABETES2, scales = "fixed")
# Out:
# plot without title

# %%
range(dat_per01$AGE)
hist(dat_per01$AGE)
# Out:
# [1] 32 70
# Plot with title “Histogram of dat_per01$AGE”

# %% [markdown]
# # Aim 3
# **Test the association of heart rate at Period 1 and incidence of diabetes in Period 2.**

# %%
dat <- dat_prep
dat_per12 <- dat %>%
    filter(PERIOD %in% c(1, 2)) %>%
    select(HEARTRTE, PERIOD, DIABETES, DIABETES2, SEX, SEX2, AGE, AGE2)
head(dat_per12, 3)
# Out:
#   HEARTRTE PERIOD DIABETES DIABETES2      SEX SEX2  AGE AGE2
# 1 80       1      0        Not a diabetic 1   Men   39  (30,40]
# 2 95       1      0        Not a diabetic 2   Women 46  (40,50]
# 3 80       2      0        Not a diabetic 2   Women 52  (50,65]

# %%
dat <- dat_per12 #%>% filter(HEARTRTE < 200)
dat$PERIOD <- factor(dat$PERIOD)

gp <- dat %>% 
    ggplot(aes(y = HEARTRTE, x=PERIOD)) +
    geom_violin(trim = FALSE, adjust = 1.1) +
    geom_jitter(
        size = 0.3, 
        width = 0.1,
        alpha = 0.2)
print(gp)
# Out:
# Warning message:
# “Removed 2 rows containing non-finite values (stat_ydensity).”Warning message:
# “Removed 2 rows containing missing values (geom_point).”
# plot without title

# %%
dat <- dat_per12
dat$HEARTRTE

# %%
dat <- dat_per12 #%>% filter(HEARTRTE < 200)
dat <- split(dat$HEARTRTE, dat$PERIOD)
t.test(dat$`1`, dat$`2`)
# Out:
# 	Welch Two Sample t-test
#
# data:  dat$`1` and dat$`2`
# t = -5.1881, df = 8116.2, p-value = 2.176e-07
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -1.9526355 -0.8817175
# sample estimates:
# mean of x mean of y
#  75.89104  77.30822
